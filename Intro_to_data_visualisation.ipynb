# %% [markdown]
# # Intro to Data Visualization with Pandas

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# %matplotlib inline

# %%
plt.style.use("fivethirtyeight")

# %% [markdown]
# ## Plotting graph with plot() method

# %%
data=pd.Series(np.random.randn(1000).cumsum())

# %%
data.plot()
# Out:
# <Axes: >

# %%
df1 = pd.DataFrame(np.random.randn(100, 4),columns=list('ABCD'))
df1
# Out:
#            A         B         C         D
# 0   0.892559  0.524063 -0.402076 -0.552574
# 1   0.786596 -0.632772 -0.722399  1.955055
# 2   0.039237  1.012829 -0.367458  0.135560
# 3   0.088454 -0.516407  0.336335 -0.666641
# 4  -0.800606  1.375289 -1.364469 -0.559325
# ..       ...       ...       ...       ...
# 95 -0.225400  0.762724 -0.005727 -1.702165
# 96 -1.665510  0.805411 -0.315010  0.380068
# 97  0.533027 -0.776717 -1.733610  1.338345
# 98 -0.396234  2.650383 -0.816042  0.192252
# 99 -1.008055 -0.815666  0.319960  0.687759
#
# [100 rows x 4 columns]

# %%
df1 = df1.cumsum()
df1
# Out:
#             A         B          C         D
# 0    0.892559  0.524063  -0.402076 -0.552574
# 1    1.679154 -0.108709  -1.124475  1.402481
# 2    1.718392  0.904121  -1.491933  1.538041
# 3    1.806846  0.387713  -1.155598  0.871400
# 4    1.006240  1.763003  -2.520067  0.312075
# ..        ...       ...        ...       ...
# 95  10.048922  6.874921 -10.900232  4.435243
# 96   8.383412  7.680333 -11.215242  4.815311
# 97   8.916438  6.903615 -12.948852  6.153655
# 98   8.520204  9.553998 -13.764893  6.345907
# 99   7.512149  8.738332 -13.444933  7.033666
#
# [100 rows x 4 columns]

# %%
df1.plot()
# Out:
# <Axes: >

# %% [markdown]
# ## Bar Charts

# %%
df1.iloc[10].plot(kind='bar')
# Out:
# <Axes: >

# %%
df2=pd.DataFrame(np.random.rand(7,3), columns=list("ABC"))

# %%
df2.plot.bar()
# Out:
# <Axes: >

# %%
df2.plot.bar(stacked=True)
# Out:
# <Axes: >

# %%
df2.plot.barh(stacked=True)
# Out:
# <Axes: >

# %% [markdown]
# ## Histograms

# %%
iris=pd.read_csv("DataSets/iris.data", header=None)
iris.columns=["sepal_length","sepal_width", "petal_length", 
              "petal_width", "species"]

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
iris.plot.hist(alpha=0.7)
# Out:
# <Axes: ylabel='Frequency'>

# %%
bins=25

# %%
iris.plot.hist(alpha=1, stacked=True, bins=25)
# Out:
# <Axes: ylabel='Frequency'>

# %%
iris["sepal_width"].plot.hist(orientation="horizontal")
# Out:
# <Axes: xlabel='Frequency'>

# %%
iris["sepal_length"].diff().hist()
# Out:
# <Axes: >

# %%
iris.hist(color="blue", alpha=1, bins=20)
# Out:
# array([[<Axes: title={'center': 'sepal_length'}>,
#         <Axes: title={'center': 'sepal_width'}>],
#        [<Axes: title={'center': 'petal_length'}>,
#         <Axes: title={'center': 'petal_width'}>]], dtype=object)

# %%
iris.hist("petal_length",by="species")
# Out:
# array([[<Axes: title={'center': 'Iris-setosa'}>,
#         <Axes: title={'center': 'Iris-versicolor'}>],
#        [<Axes: title={'center': 'Iris-virginica'}>, <Axes: >]],
#       dtype=object)

# %% [markdown]
# ## Boxplot charts

# %%
iris.plot.box()
# Out:
# <Axes: >

# %%
colors={'boxes': 'Red', 'whiskers': 'blue','medians': 'Black', 'caps': 'Green'}

# %%
iris.plot.box(color=colors)
# Out:
# <Axes: >

# %%
iris.plot.box(vert=False)
# Out:
# <Axes: >

# %%
iris.boxplot()
# Out:
# <Axes: >

# %%
plt.rcParams["figure.figsize"]=(8,8)
plt.style.use("ggplot")
iris.boxplot(by='species')
# Out:
# array([[<Axes: title={'center': 'petal_length'}, xlabel='[species]'>,
#         <Axes: title={'center': 'petal_width'}, xlabel='[species]'>],
#        [<Axes: title={'center': 'sepal_length'}, xlabel='[species]'>,
#         <Axes: title={'center': 'sepal_width'}, xlabel='[species]'>]],
#       dtype=object)
